# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")
df = pd.DataFrame(df) 
pd.set_option('display.max_columns', None) 
df[df.duplicated()]
# Out:
#        ResponseId                                         MainBranch  \
# 65437           1                     I am a developer by profession
# 65438           2                     I am a developer by profession
# 65439           3                     I am a developer by profession
# 65440           4                              I am learning to code
# 65441           5                     I am a developer by profession
# 65442           6                        I code primarily as a hobby
# 65443           7  I am not primarily a developer, but I write co...
# 65444           8                              I am learning to code
# 65445           9                        I code primarily as a hobby
# 65446          10                     I am a developer by profession
# 65447       18522                     I am a developer by profession
# 65448       49767                        I code primarily as a hobby
# 65449       51198                     I am a developer by profession
# 65450       44085                     I am a developer by profession
# 65451       22001  I am not primarily a developer, but I write co...
# 65452       35588  I am not primarily a developer, but I write co...
# 65453       50580                     I am a developer by profession
# 65454        9938                     I am a developer by profession
# 65455       40874                     I am a developer by profession
# 65456       36796                     I am a developer by profession
#
#                       Age                                         Employment  \
# 65437  Under 18 years old                                Employed, full-time
# 65438     35-44 years old                                Employed, full-time
# 65439     45-54 years old                                Employed, full-time
# 65440     18-24 years old                                 Student, full-time
# 65441     18-24 years old                                 Student, full-time
# 65442  Under 18 years old                                 Student, full-time
# 65443     35-44 years old                                Employed, full-time
# 65444     18-24 years old  Student, full-time;Not employed, but looking f...
# 65445     45-54 years old                                Employed, full-time
# 65446     35-44 years old  Independent contractor, freelancer, or self-em...
# 65447     35-44 years old                                Employed, full-time
# 65448     18-24 years old                                 Student, full-time
# 65449     25-34 years old                                Employed, full-time
# 65450     35-44 years old                                Employed, full-time
# 65451     18-24 years old                                Employed, full-time
# 65452     18-24 years old             Student, full-time;Employed, part-time
# 65453     18-24 years old            Employed, full-time;Employed, part-time
# 65454     35-44 years old  Employed, full-time;Independent contractor, fr...
# 65455     25-34 years old                                Employed, full-time
# 65456   65 years or older                                            Retired
#
#                                  RemoteWork   Check  \
# 65437                                Remote  Apples
# 65438                                Remote  Apples
# 65439                                Remote  Apples
# 65440                                   NaN  Apples
# 65441                                   NaN  Apples
# 65442                                   NaN  Apples
# 65443                                Remote  Apples
# 65444                                   NaN  Apples
# 65445                             In-person  Apples
# 65446                                Remote  Apples
# 65447                                Remote  Apples
# 65448                                   NaN  Apples
# 65449  Hybrid (some remote, some in-person)  Apples
# 65450  Hybrid (some remote, some in-person)  Apples
# 65451                                Remote  Apples
# 65452                             In-person  Apples
# 65453                                Remote  Apples
# 65454  Hybrid (some remote, some in-person)  Apples
# 65455                                Remote  Apples
# 65456                                   NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                       I don’t code outside of work
# 65444                                                NaN
# 65445                                              Hobby
# 65446                           Bootstrapping a business
# 65447                      Hobby;Freelance/contract work
# 65448                                                NaN
# 65449           Hobby;Contribute to open-source projects
# 65450                       I don’t code outside of work
# 65451  Hobby;School or academic work;Professional dev...
# 65452  Hobby;Contribute to open-source projects;Schoo...
# 65453                      Hobby;Freelance/contract work
# 65454  Bootstrapping a business;School or academic wo...
# 65455                       I don’t code outside of work
# 65456                                                NaN
#
#                                                  EdLevel  \
# 65437                          Primary/elementary school
# 65438       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65439    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65440  Some college/university study without earning ...
# 65441  Secondary school (e.g. American high school, G...
# 65442                          Primary/elementary school
# 65443     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 65444  Secondary school (e.g. American high school, G...
# 65445     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 65446    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65447       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65448                                                NaN
# 65449       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65450       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65451       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65452  Some college/university study without earning ...
# 65453  Some college/university study without earning ...
# 65454    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65455  Some college/university study without earning ...
# 65456  Some college/university study without earning ...
#
#                                                LearnCode  \
# 65437                             Books / Physical media
# 65438  Books / Physical media;Colleague;On the job tr...
# 65439  Books / Physical media;Colleague;On the job tr...
# 65440  Other online resources (e.g., videos, blogs, f...
# 65441  Other online resources (e.g., videos, blogs, f...
# 65442  School (i.e., University, College, etc);Online...
# 65443  Other online resources (e.g., videos, blogs, f...
# 65444  Other online resources (e.g., videos, blogs, f...
# 65445  Books / Physical media;Other online resources ...
# 65446  On the job training;Other online resources (e....
# 65447  Colleague;Other online resources (e.g., videos...
# 65448                                                NaN
# 65449  Books / Physical media;Online Courses or Certi...
# 65450  On the job training;Other online resources (e....
# 65451  On the job training;Other online resources (e....
# 65452  Other online resources (e.g., videos, blogs, f...
# 65453  Colleague;Other online resources (e.g., videos...
# 65454  Books / Physical media;On the job training;Oth...
# 65455  Books / Physical media;Other online resources ...
# 65456  Books / Physical media;School (i.e., Universit...
#
#                                          LearnCodeOnline  \
# 65437                                                NaN
# 65438  Technical documentation;Blogs;Books;Written Tu...
# 65439  Technical documentation;Blogs;Books;Written Tu...
# 65440  Stack Overflow;How-to videos;Interactive tutorial
# 65441  Technical documentation;Blogs;Written Tutorial...
# 65442                                                NaN
# 65443  Technical documentation;Stack Overflow;Written...
# 65444  Technical documentation;Video-based Online Cou...
# 65445        Stack Overflow;Written-based Online Courses
# 65446  Technical documentation;Blogs;Written Tutorial...
# 65447  Technical documentation;Written Tutorials;Stac...
# 65448                                                NaN
# 65449                                                NaN
# 65450  Coding sessions (live or recorded);Social Medi...
# 65451  Technical documentation;Written Tutorials;Stac...
# 65452                                                NaN
# 65453  Technical documentation;Blogs;Written Tutorial...
# 65454  Technical documentation;Blogs;Books;Stack Over...
# 65455  Technical documentation;Blogs;Books;Stack Over...
# 65456                                                NaN
#
#                                                  TechDoc YearsCode  \
# 65437                                                NaN       NaN
# 65438  API document(s) and/or SDK document(s);User gu...        20
# 65439  API document(s) and/or SDK document(s);User gu...        37
# 65440                                                NaN         4
# 65441  API document(s) and/or SDK document(s);User gu...         9
# 65442                                                NaN        10
# 65443                                                NaN         7
# 65444                         First-party knowledge base         1
# 65445                                                NaN        20
# 65446  Traditional public search engine;AI-powered se...        15
# 65447  API document(s) and/or SDK document(s);User gu...        16
# 65448                                                NaN       NaN
# 65449                                                NaN         7
# 65450                                                NaN        22
# 65451  API document(s) and/or SDK document(s);User gu...         7
# 65452                                                NaN         7
# 65453  API document(s) and/or SDK document(s);User gu...         6
# 65454  API document(s) and/or SDK document(s);User gu...        17
# 65455             API document(s) and/or SDK document(s)        12
# 65456                                                NaN        45
#
#       YearsCodePro                                        DevType  \
# 65437          NaN                                            NaN
# 65438           17                          Developer, full-stack
# 65439           27                           Developer Experience
# 65440          NaN                          Developer, full-stack
# 65441          NaN                          Developer, full-stack
# 65442          NaN                                        Student
# 65443            7                            Academic researcher
# 65444          NaN                                        Student
# 65445          NaN                            Academic researcher
# 65446           11                          Developer, full-stack
# 65447           11                            Developer, back-end
# 65448          NaN                                            NaN
# 65449            3                                  Data engineer
# 65450           20                          Developer, full-stack
# 65451            1                            Academic researcher
# 65452            2                           System administrator
# 65453            3                            Developer, back-end
# 65454           12                            Academic researcher
# 65455           10                              Developer, mobile
# 65456           45  Developer, desktop or enterprise applications
#
#                         OrgSize                 PurchaseInfluence  \
# 65437                       NaN                               NaN
# 65438                       NaN                               NaN
# 65439                       NaN                               NaN
# 65440                       NaN                               NaN
# 65441                       NaN                               NaN
# 65442                       NaN                               NaN
# 65443                       NaN                               NaN
# 65444                       NaN                               NaN
# 65445                       NaN                               NaN
# 65446                       NaN                               NaN
# 65447        10 to 19 employees     I have little or no influence
# 65448                       NaN                               NaN
# 65449      100 to 499 employees     I have little or no influence
# 65450      100 to 499 employees     I have little or no influence
# 65451              I don’t know     I have little or no influence
# 65452      100 to 499 employees  I have a great deal of influence
# 65453          2 to 9 employees  I have a great deal of influence
# 65454  1,000 to 4,999 employees             I have some influence
# 65455      100 to 499 employees     I have little or no influence
# 65456                       NaN                               NaN
#
#                                               BuyNewTool  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447  Start a free trial;Ask developers I know/work ...
# 65448                                                NaN
# 65449                                                NaN
# 65450  Ask developers I know/work with;Visit develope...
# 65451  Ask developers I know/work with;Visit develope...
# 65452  Read ratings or reviews on third party sites l...
# 65453  Start a free trial;Ask developers I know/work ...
# 65454  Start a free trial;Read ratings or reviews on ...
# 65455  Ask developers I know/work with;Read ratings o...
# 65456                                                NaN
#
#                                               BuildvsBuy  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447  Is ready-to-go but also customizable for growt...
# 65448                                                NaN
# 65449  Is ready-to-go but also customizable for growt...
# 65450  Out-of-the-box is ready to go with little need...
# 65451  Is ready-to-go but also customizable for growt...
# 65452  Is set up to be customized and needs to be eng...
# 65453  Is ready-to-go but also customizable for growt...
# 65454  Is ready-to-go but also customizable for growt...
# 65455  Is ready-to-go but also customizable for growt...
# 65456                                                NaN
#
#                                              TechEndorse  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447  Customization;Integrated developer community;R...
# 65448                                                NaN
# 65449  APIs;Customization;Integrated developer commun...
# 65450  Integrated developer community;Reputation for ...
# 65451  APIs;Customization;Connected to an open source...
# 65452                                                NaN
# 65453  APIs;Customization;Quality support system;Repu...
# 65454  APIs;Customization;Integrated developer commun...
# 65455         APIs;Reputation for quality and excellence
# 65456                                                NaN
#
#                                                  Country  \
# 65437                           United States of America
# 65438  United Kingdom of Great Britain and Northern I...
# 65439  United Kingdom of Great Britain and Northern I...
# 65440                                             Canada
# 65441                                             Norway
# 65442                           United States of America
# 65443                           United States of America
# 65444                                         Uzbekistan
# 65445  United Kingdom of Great Britain and Northern I...
# 65446                                             Serbia
# 65447                       Iran, Islamic Republic of...
# 65448                                                NaN
# 65449                                              Egypt
# 65450                           United States of America
# 65451                                              India
# 65452                                            Germany
# 65453                                            Morocco
# 65454                                            Nigeria
# 65455                                            Germany
# 65456                                             Canada
#
#                         Currency     CompTotal  \
# 65437                        NaN           NaN
# 65438                        NaN           NaN
# 65439                        NaN           NaN
# 65440                        NaN           NaN
# 65441                        NaN           NaN
# 65442                        NaN           NaN
# 65443                        NaN           NaN
# 65444                        NaN           NaN
# 65445                        NaN           NaN
# 65446                        NaN           NaN
# 65447          IRR\tIranian rial  1.080000e+10
# 65448                        NaN           NaN
# 65449        EGP\tEgyptian pound           NaN
# 65450  USD\tUnited States dollar  1.360000e+05
# 65451          INR\tIndian rupee           NaN
# 65452          EUR European Euro           NaN
# 65453       MAD\tMoroccan dirham  3.600000e+04
# 65454        NGN\tNigerian naira  1.500000e+06
# 65455          EUR European Euro           NaN
# 65456                        NaN           NaN
#
#                                   LanguageHaveWorkedWith  \
# 65437                                                NaN
# 65438  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 65439                                                 C#
# 65440  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 65441            C++;HTML/CSS;JavaScript;Lua;Python;Rust
# 65442  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 65443                                                  R
# 65444                     HTML/CSS;JavaScript;TypeScript
# 65445                                                Lua
# 65446                     HTML/CSS;JavaScript;TypeScript
# 65447  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 65448                                                NaN
# 65449                             Python;Scala;SQL;Swift
# 65450  HTML/CSS;JavaScript;PowerShell;Python;SQL;Type...
# 65451    Bash/Shell (all shells);Julia;Python;R;Rust;SQL
# 65452                                   Java;Prolog;Rust
# 65453                          JavaScript;SQL;TypeScript
# 65454  HTML/CSS;JavaScript;PHP;Python;Solidity;SQL;Ty...
# 65455                   Bash/Shell (all shells);Dart;PHP
# 65456  C;C#;C++;Fortran;HTML/CSS;JavaScript;SQL;TypeS...
#
#                                   LanguageWantToWorkWith  \
# 65437                                                NaN
# 65438  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 65439                                                 C#
# 65440  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 65441                 C++;HTML/CSS;JavaScript;Lua;Python
# 65442  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 65443                                                  R
# 65444                     HTML/CSS;JavaScript;TypeScript
# 65445                                                Lua
# 65446                     HTML/CSS;JavaScript;TypeScript
# 65447       Bash/Shell (all shells);Java;Kotlin;Rust;SQL
# 65448                                                NaN
# 65449                                   Python;Scala;SQL
# 65450                                                NaN
# 65451  Bash/Shell (all shells);C;Elixir;Erlang;Haskel...
# 65452                                        Prolog;Rust
# 65453         Go;HTML/CSS;JavaScript;Rust;SQL;TypeScript
# 65454  C++;HTML/CSS;JavaScript;MATLAB;PHP;Python;R;So...
# 65455                              JavaScript;TypeScript
# 65456                                       C#;SQL;Swift
#
#                                          LanguageAdmired  \
# 65437                                                NaN
# 65438  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 65439                                                 C#
# 65440  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 65441                 C++;HTML/CSS;JavaScript;Lua;Python
# 65442  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 65443                                                  R
# 65444                     HTML/CSS;JavaScript;TypeScript
# 65445                                                Lua
# 65446                     HTML/CSS;JavaScript;TypeScript
# 65447       Bash/Shell (all shells);Java;Kotlin;Rust;SQL
# 65448                                                NaN
# 65449                                   Python;Scala;SQL
# 65450                                                NaN
# 65451                 Bash/Shell (all shells);Julia;Rust
# 65452                                        Prolog;Rust
# 65453                          JavaScript;SQL;TypeScript
# 65454  HTML/CSS;JavaScript;PHP;Python;Solidity;SQL;Ty...
# 65455                                                NaN
# 65456                                             C#;SQL
#
#                                   DatabaseHaveWorkedWith  \
# 65437                                                NaN
# 65438                        Dynamodb;MongoDB;PostgreSQL
# 65439                         Firebase Realtime Database
# 65440                    MongoDB;MySQL;PostgreSQL;SQLite
# 65441                                  PostgreSQL;SQLite
# 65442                                    Cloud Firestore
# 65443                                                NaN
# 65444                                           Supabase
# 65445                                                NaN
# 65446                     MongoDB;MySQL;PostgreSQL;Redis
# 65447    Elasticsearch;H2;Oracle;PostgreSQL;Redis;SQLite
# 65448                                                NaN
# 65449      Elasticsearch;Microsoft SQL Server;PostgreSQL
# 65450      Cosmos DB;Databricks SQL;Microsoft SQL Server
# 65451                           MariaDB;Neo4J;PostgreSQL
# 65452                                         PostgreSQL
# 65453                      MySQL;PostgreSQL;Redis;SQLite
# 65454                               MariaDB;MySQL;SQLite
# 65455                                                NaN
# 65456  Microsoft Access;Microsoft SQL Server;MySQL;Po...
#
#                                   DatabaseWantToWorkWith  \
# 65437                                                NaN
# 65438                                         PostgreSQL
# 65439                         Firebase Realtime Database
# 65440                           MongoDB;MySQL;PostgreSQL
# 65441                                  PostgreSQL;SQLite
# 65442                                    Cloud Firestore
# 65443                                                NaN
# 65444                                           Supabase
# 65445                                                NaN
# 65446                     MongoDB;MySQL;PostgreSQL;Redis
# 65447  Cassandra;Cockroachdb;Cosmos DB;Couch DB;Couch...
# 65448                                                NaN
# 65449                           Elasticsearch;PostgreSQL
# 65450                                                NaN
# 65451                                            MariaDB
# 65452                                                NaN
# 65453                   PostgreSQL;Redis;SQLite;Supabase
# 65454                        MariaDB;MySQL;Oracle;SQLite
# 65455                                                NaN
# 65456                  Microsoft SQL Server;MySQL;SQLite
#
#                          DatabaseAdmired  \
# 65437                                NaN
# 65438                         PostgreSQL
# 65439         Firebase Realtime Database
# 65440           MongoDB;MySQL;PostgreSQL
# 65441                  PostgreSQL;SQLite
# 65442                    Cloud Firestore
# 65443                                NaN
# 65444                           Supabase
# 65445                                NaN
# 65446     MongoDB;MySQL;PostgreSQL;Redis
# 65447         H2;PostgreSQL;Redis;SQLite
# 65448                                NaN
# 65449           Elasticsearch;PostgreSQL
# 65450                                NaN
# 65451                            MariaDB
# 65452                                NaN
# 65453            PostgreSQL;Redis;SQLite
# 65454               MariaDB;MySQL;SQLite
# 65455                                NaN
# 65456  Microsoft SQL Server;MySQL;SQLite
#
#                                   PlatformHaveWorkedWith  \
# 65437                                                NaN
# 65438           Amazon Web Services (AWS);Heroku;Netlify
# 65439                                       Google Cloud
# 65440            Amazon Web Services (AWS);Fly.io;Heroku
# 65441                                                NaN
# 65442                                         Cloudflare
# 65443                                                NaN
# 65444                            Firebase;Netlify;Vercel
# 65445                                                NaN
# 65446  Amazon Web Services (AWS);Digital Ocean;Fireba...
# 65447  Amazon Web Services (AWS);Cloudflare;Firebase;...
# 65448                                                NaN
# 65449                          Amazon Web Services (AWS)
# 65450          Amazon Web Services (AWS);Microsoft Azure
# 65451                                                NaN
# 65452                                                NaN
# 65453                                     Hetzner;Render
# 65454             Amazon Web Services (AWS);Google Cloud
# 65455                                       Google Cloud
# 65456                                                NaN
#
#                                   PlatformWantToWorkWith  \
# 65437                                                NaN
# 65438           Amazon Web Services (AWS);Heroku;Netlify
# 65439                                       Google Cloud
# 65440                   Amazon Web Services (AWS);Vercel
# 65441                                                NaN
# 65442                                         Cloudflare
# 65443                                                NaN
# 65444                                             Vercel
# 65445                                                NaN
# 65446  Amazon Web Services (AWS);Digital Ocean;Fireba...
# 65447     Amazon Web Services (AWS);Google Cloud;Hetzner
# 65448                                                NaN
# 65449                          Amazon Web Services (AWS)
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                                     Hetzner;Render
# 65454             Amazon Web Services (AWS);Google Cloud
# 65455                                       Google Cloud
# 65456                                                NaN
#
#                                          PlatformAdmired  \
# 65437                                                NaN
# 65438           Amazon Web Services (AWS);Heroku;Netlify
# 65439                                       Google Cloud
# 65440                          Amazon Web Services (AWS)
# 65441                                                NaN
# 65442                                         Cloudflare
# 65443                                                NaN
# 65444                                             Vercel
# 65445                                                NaN
# 65446  Amazon Web Services (AWS);Digital Ocean;Fireba...
# 65447     Amazon Web Services (AWS);Google Cloud;Hetzner
# 65448                                                NaN
# 65449                          Amazon Web Services (AWS)
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                                     Hetzner;Render
# 65454             Amazon Web Services (AWS);Google Cloud
# 65455                                       Google Cloud
# 65456                                                NaN
#
#                               WebframeHaveWorkedWith  \
# 65437                                            NaN
# 65438                  Express;Next.js;Node.js;React
# 65439                                   ASP.NET CORE
# 65440         jQuery;Next.js;Node.js;React;WordPress
# 65441                                            NaN
# 65442                                        Node.js
# 65443                                            NaN
# 65444                                  Next.js;React
# 65445                                            NaN
# 65446                  Express;Next.js;Node.js;React
# 65447                                            NaN
# 65448                                            NaN
# 65449                                            NaN
# 65450                                        Angular
# 65451                                            NaN
# 65452                                            NaN
# 65453                                 NestJS;Node.js
# 65454  Express;jQuery;Laravel;Next.js;Node.js;Vue.js
# 65455                                            NaN
# 65456    AngularJS;ASP.NET;ASP.NET CORE;Blazor;React
#
#                                   WebframeWantToWorkWith  \
# 65437                                                NaN
# 65438                   Express;Htmx;Node.js;React;Remix
# 65439                                       ASP.NET CORE
# 65440                       jQuery;Next.js;Node.js;React
# 65441                                                NaN
# 65442                                            Node.js
# 65443                                                NaN
# 65444                                      Next.js;React
# 65445                                                NaN
# 65446                      Express;Next.js;Node.js;React
# 65447                                                NaN
# 65448                                                NaN
# 65449                                                NaN
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                               NestJS;Node.js;React
# 65454  Angular;AngularJS;Express;Flask;jQuery;Laravel...
# 65455                                                NaN
# 65456                        ASP.NET;ASP.NET CORE;Blazor
#
#                                      WebframeAdmired  \
# 65437                                            NaN
# 65438                          Express;Node.js;React
# 65439                                   ASP.NET CORE
# 65440                   jQuery;Next.js;Node.js;React
# 65441                                            NaN
# 65442                                        Node.js
# 65443                                            NaN
# 65444                                  Next.js;React
# 65445                                            NaN
# 65446                  Express;Next.js;Node.js;React
# 65447                                            NaN
# 65448                                            NaN
# 65449                                            NaN
# 65450                                            NaN
# 65451                                            NaN
# 65452                                            NaN
# 65453                                 NestJS;Node.js
# 65454  Express;jQuery;Laravel;Next.js;Node.js;Vue.js
# 65455                                            NaN
# 65456                    ASP.NET;ASP.NET CORE;Blazor
#
#                 EmbeddedHaveWorkedWith EmbeddedWantToWorkWith  \
# 65437                              NaN                    NaN
# 65438                              NaN                    NaN
# 65439                      Rasberry Pi            Rasberry Pi
# 65440                      Rasberry Pi                    NaN
# 65441          CMake;Cargo;Rasberry Pi      CMake;Rasberry Pi
# 65442                      Rasberry Pi            Rasberry Pi
# 65443                              NaN                    NaN
# 65444                              NaN                    NaN
# 65445                              NaN                    NaN
# 65446                              NaN                    NaN
# 65447                            Cargo                  Cargo
# 65448                              NaN                    NaN
# 65449                              NaN                    NaN
# 65450                              NaN                    NaN
# 65451             GNU GCC;LLVM's Clang   GNU GCC;LLVM's Clang
# 65452                              NaN                    NaN
# 65453                              NaN                    NaN
# 65454                              NaN                    NaN
# 65455                              NaN                    NaN
# 65456  Arduino;CMake;LLVM's Clang;MSVC                Arduino
#
#             EmbeddedAdmired  \
# 65437                   NaN
# 65438                   NaN
# 65439           Rasberry Pi
# 65440                   NaN
# 65441     CMake;Rasberry Pi
# 65442           Rasberry Pi
# 65443                   NaN
# 65444                   NaN
# 65445                   NaN
# 65446                   NaN
# 65447                 Cargo
# 65448                   NaN
# 65449                   NaN
# 65450                   NaN
# 65451  GNU GCC;LLVM's Clang
# 65452                   NaN
# 65453                   NaN
# 65454                   NaN
# 65455                   NaN
# 65456               Arduino
#
#                                   MiscTechHaveWorkedWith  \
# 65437                                                NaN
# 65438                                                NaN
# 65439    .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 65440                       NumPy;Pandas;Ruff;TensorFlow
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447                     Apache Kafka;GTK;Ktor;RabbitMQ
# 65448                                                NaN
# 65449                                       Apache Spark
# 65450                                                NaN
# 65451  CUDA;Keras;NumPy;Pandas;TensorFlow;Tidyverse;T...
# 65452                                                NaN
# 65453                                                NaN
# 65454                                                NaN
# 65455                                            Flutter
# 65456  .NET (5+) ;.NET Framework (1.0 - 4.8);Hadoop;M...
#
#                                 MiscTechWantToWorkWith  \
# 65437                                              NaN
# 65438                                              NaN
# 65439  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 65440                                              NaN
# 65441                                              NaN
# 65442                                              NaN
# 65443                                              NaN
# 65444                                              NaN
# 65445                                              NaN
# 65446                                              NaN
# 65447                   Apache Kafka;GTK;Ktor;RabbitMQ
# 65448                                              NaN
# 65449                                     Apache Spark
# 65450                                              NaN
# 65451                                     NumPy;Pandas
# 65452                                              NaN
# 65453                                              NaN
# 65454                                              NaN
# 65455                                              NaN
# 65456     .NET (5+) ;.NET Framework (1.0 - 4.8);Roslyn
#
#                                        MiscTechAdmired  \
# 65437                                              NaN
# 65438                                              NaN
# 65439  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 65440                                              NaN
# 65441                                              NaN
# 65442                                              NaN
# 65443                                              NaN
# 65444                                              NaN
# 65445                                              NaN
# 65446                                              NaN
# 65447                   Apache Kafka;GTK;Ktor;RabbitMQ
# 65448                                              NaN
# 65449                                     Apache Spark
# 65450                                              NaN
# 65451                                     NumPy;Pandas
# 65452                                              NaN
# 65453                                              NaN
# 65454                                              NaN
# 65455                                              NaN
# 65456     .NET (5+) ;.NET Framework (1.0 - 4.8);Roslyn
#
#                                  ToolsTechHaveWorkedWith  \
# 65437                                                NaN
# 65438        Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 65439                                            MSBuild
# 65440                                     Docker;npm;Pip
# 65441                                       APT;Make;npm
# 65442                       Docker;Homebrew;npm;Pip;pnpm
# 65443                                                NaN
# 65444                                      npm;Vite;Yarn
# 65445                                                NaN
# 65446                                        npm;Webpack
# 65447  Ansible;APT;Docker;Gradle;Kubernetes;Maven (bu...
# 65448                                                NaN
# 65449                                         Gradle;Pip
# 65450                                                NaN
# 65451                                Docker;Make;Nix;Pip
# 65452                                                Nix
# 65453                                           APT;pnpm
# 65454  Chocolatey;Composer;Homebrew;Kubernetes;npm;Vi...
# 65455                                      Homebrew;Make
# 65456  Docker;MSBuild;NuGet;Unity 3D;Visual Studio So...
#
#                                  ToolsTechWantToWorkWith  \
# 65437                                                NaN
# 65438        Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 65439                                            MSBuild
# 65440                              Docker;Kubernetes;npm
# 65441                                           APT;Make
# 65442                              Homebrew;npm;Pip;pnpm
# 65443                                                NaN
# 65444                                           npm;Vite
# 65445                                                NaN
# 65446                                        npm;Webpack
# 65447  Ansible;Docker;Kubernetes;Maven (build tool);P...
# 65448                                                NaN
# 65449                                         Gradle;Pip
# 65450                                                NaN
# 65451                                    Docker;Make;Nix
# 65452                                                Nix
# 65453                                           APT;pnpm
# 65454  Chocolatey;Composer;Homebrew;Kubernetes;npm;Pi...
# 65455                                                NaN
# 65456  MSBuild;NuGet;Unity 3D;Unreal Engine;Visual St...
#
#                                         ToolsTechAdmired  \
# 65437                                                NaN
# 65438        Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 65439                                            MSBuild
# 65440                                         Docker;npm
# 65441                                           APT;Make
# 65442                              Homebrew;npm;Pip;pnpm
# 65443                                                NaN
# 65444                                           npm;Vite
# 65445                                                NaN
# 65446                                        npm;Webpack
# 65447  Ansible;Docker;Kubernetes;Maven (build tool);P...
# 65448                                                NaN
# 65449                                         Gradle;Pip
# 65450                                                NaN
# 65451                                    Docker;Make;Nix
# 65452                                                Nix
# 65453                                           APT;pnpm
# 65454   Chocolatey;Composer;Homebrew;Kubernetes;npm;Vite
# 65455                                                NaN
# 65456      MSBuild;NuGet;Unity 3D;Visual Studio Solution
#
#                             NEWCollabToolsHaveWorkedWith  \
# 65437                                                NaN
# 65438                PyCharm;Visual Studio Code;WebStorm
# 65439                                      Visual Studio
# 65440                                                NaN
# 65441                                                Vim
# 65442                  Nano;Vim;Visual Studio Code;Xcode
# 65443                                            RStudio
# 65444                                 Visual Studio Code
# 65445                                 Visual Studio Code
# 65446                                 Visual Studio Code
# 65447                             IntelliJ IDEA;Nano;Vim
# 65448                                                NaN
# 65449                   IntelliJ IDEA;Visual Studio Code
# 65450                       Notepad++;Visual Studio Code
# 65451  Helix;IPython;Jupyter Notebook/JupyterLab;Kate...
# 65452                                             Neovim
# 65453                                 Visual Studio Code
# 65454  Jupyter Notebook/JupyterLab;Notepad++;Visual S...
# 65455                                 Visual Studio Code
# 65456         Notepad++;Visual Studio;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith  \
# 65437                                                NaN
# 65438                PyCharm;Visual Studio Code;WebStorm
# 65439                                      Visual Studio
# 65440                                                NaN
# 65441                                                Vim
# 65442                  Nano;Vim;Visual Studio Code;Xcode
# 65443                                            RStudio
# 65444                                 Visual Studio Code
# 65445                                 Visual Studio Code
# 65446                                 Visual Studio Code
# 65447                                      IntelliJ IDEA
# 65448                                                NaN
# 65449                   IntelliJ IDEA;Visual Studio Code
# 65450                                                NaN
# 65451  IPython;Jupyter Notebook/JupyterLab;Kate;Neovi...
# 65452                                             Neovim
# 65453                                 Visual Studio Code
# 65454  Android Studio;Jupyter Notebook/JupyterLab;Not...
# 65455                                 Visual Studio Code
# 65456                            Notepad++;Visual Studio
#
#                                    NEWCollabToolsAdmired  \
# 65437                                                NaN
# 65438                PyCharm;Visual Studio Code;WebStorm
# 65439                                      Visual Studio
# 65440                                                NaN
# 65441                                                Vim
# 65442                  Nano;Vim;Visual Studio Code;Xcode
# 65443                                            RStudio
# 65444                                 Visual Studio Code
# 65445                                 Visual Studio Code
# 65446                                 Visual Studio Code
# 65447                                      IntelliJ IDEA
# 65448                                                NaN
# 65449                   IntelliJ IDEA;Visual Studio Code
# 65450                                                NaN
# 65451  IPython;Jupyter Notebook/JupyterLab;Kate;Neovi...
# 65452                                             Neovim
# 65453                                 Visual Studio Code
# 65454  Jupyter Notebook/JupyterLab;Notepad++;Visual S...
# 65455                                 Visual Studio Code
# 65456                            Notepad++;Visual Studio
#
#                                        OpSysPersonal use  \
# 65437                                                NaN
# 65438                                      MacOS;Windows
# ...
# 65444                         NaN                         NaN
# 65445                         NaN                         NaN
# 65446                         NaN                         NaN
# 65447                    Disagree                       Agree
# 65448                         NaN                         NaN
# 65449                         NaN                         NaN
# 65450                         NaN                         NaN
# 65451                         NaN                         NaN
# 65452                         NaN                         NaN
# 65453  Neither agree nor disagree  Neither agree nor disagree
# 65454                       Agree                       Agree
# 65455                       Agree                    Disagree
# 65456                         NaN                         NaN
#
#                       Knowledge_8                 Knowledge_9  \
# 65437                         NaN                         NaN
# 65438                       Agree                       Agree
# 65439                         NaN                         NaN
# 65440                         NaN                         NaN
# 65441                         NaN                         NaN
# 65442                         NaN                         NaN
# 65443                         NaN                         NaN
# 65444                         NaN                         NaN
# 65445                         NaN                         NaN
# 65446                         NaN                         NaN
# 65447                       Agree                    Disagree
# 65448                         NaN                         NaN
# 65449                         NaN                         NaN
# 65450                         NaN                         NaN
# 65451                         NaN                         NaN
# 65452                         NaN                         NaN
# 65453                    Disagree                    Disagree
# 65454                       Agree                       Agree
# 65455  Neither agree nor disagree  Neither agree nor disagree
# 65456                         NaN                         NaN
#
#             Frequency_1        Frequency_2        Frequency_3  \
# 65437               NaN                NaN                NaN
# 65438               NaN                NaN                NaN
# 65439               NaN                NaN                NaN
# 65440               NaN                NaN                NaN
# 65441               NaN                NaN                NaN
# 65442               NaN                NaN                NaN
# 65443               NaN                NaN                NaN
# 65444               NaN                NaN                NaN
# 65445               NaN                NaN                NaN
# 65446               NaN                NaN                NaN
# 65447  1-2 times a week   1-2 times a week   1-2 times a week
# 65448               NaN                NaN                NaN
# 65449  1-2 times a week   3-5 times a week  6-10 times a week
# 65450               NaN                NaN                NaN
# 65451               NaN                NaN                NaN
# 65452               NaN                NaN                NaN
# 65453             Never              Never              Never
# 65454  1-2 times a week  6-10 times a week   1-2 times a week
# 65455             Never   1-2 times a week              Never
# 65456               NaN                NaN                NaN
#
#                 TimeSearching               TimeAnswering  \
# 65437                     NaN                         NaN
# 65438                     NaN                         NaN
# 65439                     NaN                         NaN
# 65440                     NaN                         NaN
# 65441                     NaN                         NaN
# 65442                     NaN                         NaN
# 65443                     NaN                         NaN
# 65444                     NaN                         NaN
# 65445                     NaN                         NaN
# 65446                     NaN                         NaN
# 65447  Over 120 minutes a day  Less than 15 minutes a day
# 65448                     NaN                         NaN
# 65449     30-60 minutes a day         30-60 minutes a day
# 65450                     NaN                         NaN
# 65451                     NaN                         NaN
# 65452                     NaN                         NaN
# 65453    60-120 minutes a day         30-60 minutes a day
# 65454     30-60 minutes a day  Less than 15 minutes a day
# 65455     30-60 minutes a day  Less than 15 minutes a day
# 65456                     NaN                         NaN
#
#                                              Frustration  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447                           Amount of technical debt
# 65448                                                NaN
# 65449  Amount of technical debt;Tracking my work;Show...
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                                                NaN
# 65454  Number of software tools in use;Tracking my wo...
# 65455                           Amount of technical debt
# 65456                                                NaN
#
#                                         ProfessionalTech  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447  DevOps function;Automated testing;Microservice...
# 65448                                                NaN
# 65449                                                NaN
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                                      None of these
# 65454                        Knowledge sharing community
# 65455  Knowledge sharing community;Continuous integra...
# 65456                                                NaN
#
#                         ProfessionalCloud  \
# 65437                                 NaN
# 65438                                 NaN
# 65439                                 NaN
# 65440                                 NaN
# 65441                                 NaN
# 65442                                 NaN
# 65443                                 NaN
# 65444                                 NaN
# 65445                                 NaN
# 65446                                 NaN
# 65447          Hybrid (on-prem and cloud)
# 65448                                 NaN
# 65449                             On-prem
# 65450                                 NaN
# 65451                                 NaN
# 65452                                 NaN
# 65453  Cloud only (single or multi-cloud)
# 65454                             On-prem
# 65455  Cloud only (single or multi-cloud)
# 65456                                 NaN
#
#                                     ProfessionalQuestion  \
# 65437                                                NaN
# 65438                                                NaN
# 65439                                                NaN
# 65440                                                NaN
# 65441                                                NaN
# 65442                                                NaN
# 65443                                                NaN
# 65444                                                NaN
# 65445                                                NaN
# 65446                                                NaN
# 65447                   Traditional public search engine
# 65448                                                NaN
# 65449                                         A coworker
# 65450                                                NaN
# 65451                                                NaN
# 65452                                                NaN
# 65453                           AI-powered search (free)
# 65454  Do search of internal share drives/storage loc...
# 65455                   Traditional public search engine
# 65456                                                NaN
#
#                               Industry  JobSatPoints_1  JobSatPoints_4  \
# 65437                              NaN             NaN             NaN
# 65438                              NaN             0.0             0.0
# 65439                              NaN             NaN             NaN
# 65440                              NaN             NaN             NaN
# 65441                              NaN             NaN             NaN
# 65442                              NaN             NaN             NaN
# 65443                              NaN             NaN             NaN
# 65444                              NaN             NaN             NaN
# 65445                              NaN             NaN             NaN
# 65446                              NaN             NaN             NaN
# 65447  Transportation, or Supply Chain             0.0             0.0
# 65448                              NaN             NaN             NaN
# 65449             Software Development             0.0             0.0
# 65450                              NaN             NaN             NaN
# 65451                              NaN             NaN             NaN
# 65452                              NaN             NaN             NaN
# 65453                           Other:            50.0             0.0
# 65454                 Higher Education             0.0             0.0
# 65455     Retail and Consumer Services             0.0             0.0
# 65456                              NaN             NaN             NaN
#
#        JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# 65437             NaN             NaN             NaN             NaN
# 65438             0.0             0.0             0.0             0.0
# 65439             NaN             NaN             NaN             NaN
# 65440             NaN             NaN             NaN             NaN
# 65441             NaN             NaN             NaN             NaN
# 65442             NaN             NaN             NaN             NaN
# 65443             NaN             NaN             NaN             NaN
# 65444             NaN             NaN             NaN             NaN
# 65445             NaN             NaN             NaN             NaN
# 65446             NaN             NaN             NaN             NaN
# 65447             0.0             0.0             0.0             0.0
# 65448             NaN             NaN             NaN             NaN
# 65449             0.0             0.0             0.0             0.0
# 65450             NaN             NaN             NaN             NaN
# 65451             NaN             NaN             NaN             NaN
# 65452             NaN             NaN             NaN             NaN
# 65453            10.0            50.0            50.0            90.0
# 65454            10.0             0.0            60.0            60.0
# 65455             0.0             0.0             0.0             0.0
# 65456             NaN             NaN             NaN             NaN
#
#        JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# 65437             NaN              NaN              NaN
# 65438             0.0              0.0              0.0
# 65439             NaN              NaN              NaN
# 65440             NaN              NaN              NaN
# 65441             NaN              NaN              NaN
# 65442             NaN              NaN              NaN
# 65443             NaN              NaN              NaN
# 65444             NaN              NaN              NaN
# 65445             NaN              NaN              NaN
# 65446             NaN              NaN              NaN
# 65447             0.0              0.0              0.0
# 65448             NaN              NaN              NaN
# 65449             0.0              0.0              0.0
# 65450             NaN              NaN              NaN
# 65451             NaN              NaN              NaN
# 65452             NaN              NaN              NaN
# 65453             0.0              0.0              0.0
# 65454            50.0              0.0             50.0
# 65455             0.0              0.0              0.0
# 65456             NaN              NaN              NaN
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly  \
# 65437                    NaN                         NaN                  NaN
# 65438                    NaN                         NaN                  NaN
# 65439  Appropriate in length                        Easy                  NaN
# 65440               Too long                        Easy                  NaN
# 65441              Too short                        Easy                  NaN
# 65442  Appropriate in length                        Easy                  NaN
# 65443               Too long  Neither easy nor difficult                  NaN
# 65444  Appropriate in length                   Difficult                  NaN
# 65445  Appropriate in length  Neither easy nor difficult                  NaN
# 65446               Too long                        Easy                  NaN
# 65447                    NaN  Neither easy nor difficult             256608.0
# 65448                    NaN                         NaN                  NaN
# 65449  Appropriate in length  Neither easy nor difficult                  NaN
# 65450  Appropriate in length                        Easy                  NaN
# 65451  Appropriate in length                        Easy                  NaN
# 65452  Appropriate in length  Neither easy nor difficult                  NaN
# 65453               Too long                        Easy                  NaN
# 65454  Appropriate in length                        Easy                997.0
# 65455  Appropriate in length  Neither easy nor difficult                  NaN
# 65456  Appropriate in length                        Easy                  NaN
#
#        JobSat
# 65437     NaN
# 65438     NaN
# 65439     NaN
# 65440     NaN
# 65441     NaN
# 65442     NaN
# 65443     NaN
# 65444     NaN
# 65445     NaN
# 65446     NaN
# 65447     9.0
# 65448     NaN
# 65449     3.0
# 65450     NaN
# 65451     NaN
# 65452     NaN
# 65453     9.0
# 65454     4.0
# 65455     6.0
# 65456     NaN

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
duplicated_rows = df[df.duplicated()]
len(duplicated_rows)
# Out:
# 20

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
df.shape
# Out:
# (65437, 114)

# %%
## Write your code here
df_bar_country = df_duplicates['Country']
df_bar_employment = df_duplicates['Employment']
df_duplicates.plot(x='Country', y='ResponseId', kind='bar')
plt.show()

# %%
df_duplicates.plot(x='Employment', y='ResponseId', kind='bar')
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
df_duplicates.drop_duplicates(subset = 'Country')
# Out:
#        ResponseId                                         MainBranch  \
# 65437           1                     I am a developer by profession
# 65438           2                     I am a developer by profession
# 65440           4                              I am learning to code
# 65441           5                     I am a developer by profession
# 65444           8                              I am learning to code
# 65446          10                     I am a developer by profession
# 65454        9938                     I am a developer by profession
# 65447       18522                     I am a developer by profession
# 65451       22001  I am not primarily a developer, but I write co...
# 65452       35588  I am not primarily a developer, but I write co...
# 65448       49767                        I code primarily as a hobby
# 65453       50580                     I am a developer by profession
# 65449       51198                     I am a developer by profession
#
#                       Age                                         Employment  \
# 65437  Under 18 years old                                Employed, full-time
# 65438     35-44 years old                                Employed, full-time
# 65440     18-24 years old                                 Student, full-time
# 65441     18-24 years old                                 Student, full-time
# 65444     18-24 years old  Student, full-time;Not employed, but looking f...
# 65446     35-44 years old  Independent contractor, freelancer, or self-em...
# 65454     35-44 years old  Employed, full-time;Independent contractor, fr...
# 65447     35-44 years old                                Employed, full-time
# 65451     18-24 years old                                Employed, full-time
# 65452     18-24 years old             Student, full-time;Employed, part-time
# 65448     18-24 years old                                 Student, full-time
# 65453     18-24 years old            Employed, full-time;Employed, part-time
# 65449     25-34 years old                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 65437                                Remote  Apples
# 65438                                Remote  Apples
# 65440                                   NaN  Apples
# 65441                                   NaN  Apples
# 65444                                   NaN  Apples
# 65446                                Remote  Apples
# 65454  Hybrid (some remote, some in-person)  Apples
# 65447                                Remote  Apples
# 65451                                Remote  Apples
# 65452                             In-person  Apples
# 65448                                   NaN  Apples
# 65453                                Remote  Apples
# 65449  Hybrid (some remote, some in-person)  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65440                                                NaN
# 65441                                                NaN
# 65444                                                NaN
# 65446                           Bootstrapping a business
# 65454  Bootstrapping a business;School or academic wo...
# 65447                      Hobby;Freelance/contract work
# 65451  Hobby;School or academic work;Professional dev...
# 65452  Hobby;Contribute to open-source projects;Schoo...
# 65448                                                NaN
# 65453                      Hobby;Freelance/contract work
# 65449           Hobby;Contribute to open-source projects
#
#                                                  EdLevel  \
# 65437                          Primary/elementary school
# 65438       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65440  Some college/university study without earning ...
# 65441  Secondary school (e.g. American high school, G...
# 65444  Secondary school (e.g. American high school, G...
# 65446    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65454    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65447       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65451       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65452  Some college/university study without earning ...
# 65448                                                NaN
# 65453  Some college/university study without earning ...
# 65449       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 65437                             Books / Physical media
# 65438  Books / Physical media;Colleague;On the job tr...
# 65440  Other online resources (e.g., videos, blogs, f...
# 65441  Other online resources (e.g., videos, blogs, f...
# 65444  Other online resources (e.g., videos, blogs, f...
# 65446  On the job training;Other online resources (e....
# 65454  Books / Physical media;On the job training;Oth...
# 65447  Colleague;Other online resources (e.g., videos...
# 65451  On the job training;Other online resources (e....
# 65452  Other online resources (e.g., videos, blogs, f...
# 65448                                                NaN
# 65453  Colleague;Other online resources (e.g., videos...
# 65449  Books / Physical media;Online Courses or Certi...
#
#                                          LearnCodeOnline  ... JobSatPoints_6  \
# 65437                                                NaN  ...            NaN
# 65438  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 65440  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 65441  Technical documentation;Blogs;Written Tutorial...  ...            NaN
# 65444  Technical documentation;Video-based Online Cou...  ...            NaN
# 65446  Technical documentation;Blogs;Written Tutorial...  ...            NaN
# 65454  Technical documentation;Blogs;Books;Stack Over...  ...            0.0
# 65447  Technical documentation;Written Tutorials;Stac...  ...            0.0
# 65451  Technical documentation;Written Tutorials;Stac...  ...            NaN
# 65452                                                NaN  ...            NaN
# 65448                                                NaN  ...            NaN
# 65453  Technical documentation;Blogs;Written Tutorial...  ...           50.0
# 65449                                                NaN  ...            0.0
#
#       JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 65437            NaN            NaN            NaN             NaN
# 65438            0.0            0.0            0.0             0.0
# 65440            NaN            NaN            NaN             NaN
# 65441            NaN            NaN            NaN             NaN
# 65444            NaN            NaN            NaN             NaN
# 65446            NaN            NaN            NaN             NaN
# 65454           60.0           60.0           50.0             0.0
# 65447            0.0            0.0            0.0             0.0
# 65451            NaN            NaN            NaN             NaN
# 65452            NaN            NaN            NaN             NaN
# 65448            NaN            NaN            NaN             NaN
# 65453           50.0           90.0            0.0             0.0
# 65449            0.0            0.0            0.0             0.0
#
#       JobSatPoints_11           SurveyLength                  SurveyEase  \
# 65437             NaN                    NaN                         NaN
# 65438             0.0                    NaN                         NaN
# 65440             NaN               Too long                        Easy
# 65441             NaN              Too short                        Easy
# 65444             NaN  Appropriate in length                   Difficult
# 65446             NaN               Too long                        Easy
# 65454            50.0  Appropriate in length                        Easy
# 65447             0.0                    NaN  Neither easy nor difficult
# 65451             NaN  Appropriate in length                        Easy
# 65452             NaN  Appropriate in length  Neither easy nor difficult
# 65448             NaN                    NaN                         NaN
# 65453             0.0               Too long                        Easy
# 65449             0.0  Appropriate in length  Neither easy nor difficult
#
#       ConvertedCompYearly JobSat
# 65437                 NaN    NaN
# 65438                 NaN    NaN
# 65440                 NaN    NaN
# 65441                 NaN    NaN
# 65444                 NaN    NaN
# 65446                 NaN    NaN
# 65454               997.0    4.0
# 65447            256608.0    9.0
# 65451                 NaN    NaN
# 65452                 NaN    NaN
# 65448                 NaN    NaN
# 65453                 NaN    9.0
# 65449                 NaN    3.0
#
# [13 rows x 114 columns]

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# I identified the unique values using the column Country

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
